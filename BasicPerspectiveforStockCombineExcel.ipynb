# %%
#combine all excel into one excel with multiple sheets
import win32com.client as win32
import os

excel = win32.gencache.EnsureDispatch('Excel.Application')
wb = excel.Workbooks.Add()

for f in [os.path.join(os.getcwd(), "Styled_Basic_Perspective_EPS.xlsx"), os.path.join(os.getcwd(), "Styled_Basic_Perspective_NetIncome.xlsx"), os.path.join(os.getcwd(), "Styled_Basic_Perspective_OperationProfit.xlsx"), os.path.join(os.getcwd(), "Styled_Basic_Perspective_GrossProfit.xlsx"), os.path.join(os.getcwd(), "Styled_Basic_Perspective_Revenue.xlsx")]: 
    w = excel.Workbooks.Open(f) 
    w.Sheets(1).Copy(wb.Sheets(1))

wb.SaveAs(os.path.join(os.getcwd(), "Styled_Basic_Perspective_Total.xlsx"))
wb.SaveAs(os.path.join(os.getcwd(), "Styled_Basic_Perspective_Total.xls"))
excel.Application.Quit()
# Out:
# ---------------------------------------------------------------------------
# com_error                                 Traceback (most recent call last)
# <ipython-input-1-9637f323faff> in <module>()
#      10     w.Sheets(1).Copy(wb.Sheets(1))
#      11
# ---> 12 wb.SaveAs(os.path.join(os.getcwd(), "Styled_Basic_Perspective_Total.xlsx"))
#      13 wb.SaveAs(os.path.join(os.getcwd(), "Styled_Basic_Perspective_Total.xls"))
#      14 excel.Application.Quit()
#
# C:\Users\TERREN~1\AppData\Local\Temp\gen_py\3.5\00020813-0000-0000-C000-000000000046x0x1x9\_Workbook.py in SaveAs(self, Filename, FileFormat, Password, WriteResPassword, ReadOnlyRecommended, CreateBackup, AccessMode, ConflictResolution, AddToMru, TextCodepage, TextVisualLayout, Local, WorkIdentity)
#     283                         , FileFormat, Password, WriteResPassword, ReadOnlyRecommended, CreateBackup
#     284                         , AccessMode, ConflictResolution, AddToMru, TextCodepage, TextVisualLayout
# --> 285 			, Local, WorkIdentity)
#     286
#     287         def SaveAsXMLData(self, Filename=defaultNamedNotOptArg, Map=defaultNamedNotOptArg):
#
# com_error: (-2147352567, 'Exception occurred.', (0, 'Microsoft Excel', 'SaveAs method of Workbook class failed', 'xlmain11.chm', 0, -2146827284), None)

# %%
# it the above program have the following error, please the below program to combine excels to one excel file
# com_error: (-2147352567, 'Exception occurred.', (0, 'Microsoft Excel', 'SaveAs method of Workbook class failed', 'xlmain11.chm', 0, -2146827284), None)

import pandas as pd

df1 = pd.read_excel('Styled_Basic_Perspective_Revenue.xlsx')
df2 = pd.read_excel('Styled_Basic_Perspective_GrossProfit.xlsx')
df3 = pd.read_excel('Styled_Basic_Perspective_OperationProfit.xlsx')
df4 = pd.read_excel('Styled_Basic_Perspective_NetIncome.xlsx')
df5 = pd.read_excel('Styled_Basic_Perspective_EPS.xlsx')

# pandas styling
def color_white(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'white'
    return 'color: %s' % color

def background_color(val):    
    if float(val) < 0:
        backgroundcolor = '#ff0000'
    elif float(val) < 10:
        backgroundcolor = '#f47721'
    elif float(val) < 20:
        backgroundcolor = '#ffdd00'
    elif float(val) < 30:
        backgroundcolor = '#5ecc62'
    else:
        backgroundcolor = '#00ad45'
    return 'background-color: %s' % backgroundcolor

# styled dataframe can use .to_excel('Styled_Basic_EPS.xlsx', engine='openpyxl') to export excel with style
year = 107
season = 1
howmany_year_data = 3

columns_name = []
for i in range(int(howmany_year_data*4-4)):
    columns_name.append('Growth_{0}Q{1}'.format(year, season))
    columns_name.append('2QMAGrowth_{0}Q{1}'.format(year, season))
    if (season != 1):
        season = season - 1
    else:
        season = 4
        year = year - 1

        
writer = pd.ExcelWriter('Styled_Basic_Perspective_Total.xlsx')
df1.style.applymap(color_white, subset=pd.IndexSlice[:, columns_name]).applymap(background_color, subset=pd.IndexSlice[:, columns_name]).to_excel(writer,'Revenue_Basic')
df2.style.applymap(color_white, subset=pd.IndexSlice[:, columns_name]).applymap(background_color, subset=pd.IndexSlice[:, columns_name]).to_excel(writer,'GrossProfit_Basic')
df3.style.applymap(color_white, subset=pd.IndexSlice[:, columns_name]).applymap(background_color, subset=pd.IndexSlice[:, columns_name]).to_excel(writer,'OperationProfit_Basic')
df4.style.applymap(color_white, subset=pd.IndexSlice[:, columns_name]).applymap(background_color, subset=pd.IndexSlice[:, columns_name]).to_excel(writer,'NetIncome_Basic')
df5.style.applymap(color_white, subset=pd.IndexSlice[:, columns_name]).applymap(background_color, subset=pd.IndexSlice[:, columns_name]).to_excel(writer,'EPS_Basic')
writer.save()
# Out:
# C:\Users\terrencechen\AppData\Local\conda\conda\envs\python35\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)

# %%
import csv
import numpy

# https://gist.github.com/dettmering/3767366
# https://docs.python.org/2/library/csv.html
def readcsvToArrayPython27(filename):    
    ifile = open(filename, "rU") # DeprecationWarning: 'U' mode is deprecated
    # What does the "U" do in the "rU", because I know r is read.
    # its universal newlines mode. I think it allows each new line in a csv to be a separate item in the reader/ifile array. 
    # So basically it will recognize the following character sequences as new lines.:
    # Unix end-of-line convention '\n', the Windows convention '\r\n', and the old Macintosh convention '\r'
    
    reader = csv.reader(ifile, delimiter=",")        
    array_stock_code = []

    for row in reader:
        if(row[0] != "StockCode"):
            array_stock_code.append(row[0])                
    
    ifile.close()
    return array_stock_code

# https://docs.python.org/3.5/library/csv.html
def readcsvToArrayPython35(filename):
    with open(filename, newline='') as f:
        reader = csv.reader(f, delimiter=',')                        
        array_stock_code = []
                    
        for row in reader:            
            #print(row) # list
            # ['StockCode']
            # ['1101']
            # ['1109']
            # ...
            
            #print(row[0]) # string
            # StockCode
            # 1101
            # 1109
            # ...
            if(row[0] != "StockCode"):
                array_stock_code.append(row[0])            
        
    return array_stock_code

# pandas styling
def color_white(val):
    """
    Takes a scalar and returns a string with
    the css property `'color: red'` for negative
    strings, black otherwise.
    """
    color = 'white'
    return 'color: %s' % color

def background_color(val):    
    if float(val) < 0:
        backgroundcolor = '#ff0000'
    elif float(val) < 10:
        backgroundcolor = '#f47721'
    elif float(val) < 20:
        backgroundcolor = '#ffdd00'
    elif float(val) < 30:
        backgroundcolor = '#5ecc62'
    else:
        backgroundcolor = '#00ad45'
    return 'background-color: %s' % backgroundcolor

# styled dataframe can use .to_excel('Styled_Basic_EPS.xlsx', engine='openpyxl') to export excel with style
year = 107
season = 1
howmany_year_data = 3

columns_name = []
for i in range(int(howmany_year_data*4-4)):
    columns_name.append('Growth_{0}Q{1}'.format(year, season))
    columns_name.append('2QMAGrowth_{0}Q{1}'.format(year, season))
    if (season != 1):
        season = season - 1
    else:
        season = 4
        year = year - 1


# https://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.filter.html

stock_code = readcsvToArrayPython35('StockCode.csv')
print(stock_code)
'''
[['StockCode'], ['1101'], ['1109'], ['1201'], ...] #stock_code is nested list when function return array_stock_code.append(row)
['StockCode', '1101', '1109', '1201', '1210', ...] #stock_code is list when function return array_stock_code.append(row[0])

'''

'''
To select rows whose column value equals a scalar, some_value, use ==:
df.loc[df['column_name'] == some_value]

To select rows whose column value is in an iterable, some_values, use isin:
df.loc[df['column_name'].isin(some_values)]

Combine multiple conditions with &:
df.loc[(df['column_name'] == some_value) & df['other_column'].isin(some_values)]

To select rows whose column value does not equal some_value, use !=:
df.loc[df['column_name'] != some_value]

isin returns a boolean Series, so to select rows whose value is not in some_values, negate the boolean Series using ~:
df.loc[~df['column_name'].isin(some_values)]
'''
# df1.loc[df['公司代號'].isin(['one','three'])]
# if StockCode string existed in filter condition value. then isin cannot filter the rows we want => it's 0 rows

writer = pd.ExcelWriter('Styled_Basic_Perspective_Total_WithSomeCompany.xlsx')
df_Revenue_Basic = df1.loc[df1['公司代號'].isin(stock_code)]
df_GrossProfit_Basic = df2.loc[df2['公司代號'].isin(stock_code)]
df_OperationProfit_Basic = df3.loc[df3['公司代號'].isin(stock_code)]
df_NetIncome_Basic = df4.loc[df4['公司代號'].isin(stock_code)]
df_EPS_Basic = df5.loc[df5['公司代號'].isin(stock_code)]

df_Revenue_Basic.style.applymap(color_white, subset=pd.IndexSlice[:, columns_name]).applymap(background_color, subset=pd.IndexSlice[:, columns_name]).to_excel(writer,'Revenue_Basic')
df_GrossProfit_Basic.style.applymap(color_white, subset=pd.IndexSlice[:, columns_name]).applymap(background_color, subset=pd.IndexSlice[:, columns_name]).to_excel(writer,'GrossProfit_Basic')
df_OperationProfit_Basic.style.applymap(color_white, subset=pd.IndexSlice[:, columns_name]).applymap(background_color, subset=pd.IndexSlice[:, columns_name]).to_excel(writer,'OperationProfit_Basic')
df_NetIncome_Basic.style.applymap(color_white, subset=pd.IndexSlice[:, columns_name]).applymap(background_color, subset=pd.IndexSlice[:, columns_name]).to_excel(writer,'NetIncome_Basic')
df_EPS_Basic.style.applymap(color_white, subset=pd.IndexSlice[:, columns_name]).applymap(background_color, subset=pd.IndexSlice[:, columns_name]).to_excel(writer,'EPS_Basic')
writer.save()
# Out:
# ['1102', '1109', '1210', '1216', '1220', '1225', '1231', '1232', '1233', '1235', '1301', '1303', '1310', '1315', '1402', '1409', '1434', '1437', '1441', '1443', '1446', '1468', '1470', '1474', '1530', '1701', '1704', '1707', '1710', '1712', '1730', '1762', '1773', '2059', '2108', '2114', '2206', '2221', '2303', '2329', '2360', '2371', '2397', '2414', '2442', '2458', '2530', '2534', '2539', '2596', '2608', '2702', '2712', '2812', '2834', '2838', '2845', '2849', '2850', '2851', '2856', '2883', '2884', '2886', '2887', '2889', '2890', '2892', '2903', '2910', '2912', '2915', '3004', '3005', '3023', '3033', '3064', '3088', '3114', '3290', '3299', '3388', '3402', '3491', '3521', '3533', '3596', '3702', '4103', '4104', '4114', '4119', '4123', '4137', '4190', '4205', '4305', '4416', '4526', '4543', '4712', '4736', '4939', '4942', '4953', '4984', '5011', '5205', '5269', '5347', '5432', '5443', '5515', '5525', '5533', '5534', '5601', '5820', '5880', '6112', '6138', '6147', '6160', '6190', '6192', '6207', '6218', '6221', '6222', '6227', '6281', '6283', '6294', '6411', '6417', '6504', '6509', '6542', '8109', '8112', '8354', '8415', '8424', '8436', '8908', '8916', '8927', '8942', '8996', '910322', '910708', '9910', '9943']
# C:\Users\terrencechen\AppData\Local\conda\conda\envs\python35\lib\site-packages\pandas\core\indexing.py:1472: FutureWarning:
# Passing list-likes to .loc or [] with any missing label will raise
# KeyError in the future, you can use .reindex() as an alternative.
#
# See the documentation here:
# https://pandas.pydata.org/pandas-docs/stable/indexing.html#deprecate-loc-reindex-listlike
#   return self._getitem_tuple(key)
